# %%
import pandas as pd

# %%
df = pd.read_excel('시군구별_및_연령별_등록외국인_현황_20231010120546.xlsx')
df1 = pd.read_csv('foreign_residence4.csv', encoding = 'cp949')
# Out:
# C:\Users\INTEL WIN11PRO(12TH)\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
result = pd.merge(df, df1, on='district', how='inner')

# %%
result.to_csv('행정구별_유동인구_소득.csv', encoding = 'utf-8-sig')

# %%
df2 = pd.read_csv('ak_dmstc_act_cltur_pblprfr_fclty_frnr_utiliiza_actcond_info_202208.csv', encoding = 'utf-8')

# %%
df2= df2[df2['SIGNGU_NM'].str.contains('서울특별시')]

# %%
df2 = df2[['SIGNGU_NM' ,'FRNR_ALL_EXPNDTR_PRICE']]

# %%
df2['SIGNGU_NM'] = df2['SIGNGU_NM'].str[6:]

# %%
grouped = df2.groupby('SIGNGU_NM')['FRNR_ALL_EXPNDTR_PRICE'].sum().to_frame().reset_index()

# %%
result
# Out:
#    district Res_population_2015 Res_population_2016 Res_population_2017  \
# 0       강남구                5265                5025                4888
# 1       강동구                4663                4303                4136
# 2       강북구                3553                3509                3523
# 3       강서구                6617                6619                6564
# 4       관악구               19368               18756               17632
# 5       광진구               14811               14889               14595
# 6       구로구               32512               32049               30817
# 7       금천구               19883               19268               18337
# 8       노원구                3638                3631                3672
# 9      동대문구               13671               15243               15364
# 10      동작구               12133               12250               12276
# 11      마포구               10708               10995               10868
# ...

# %%
final_result = pd.merge(result, grouped, left_on='district', right_on='SIGNGU_NM', how='inner')

# %%
final_result.to_csv('행정구별_상주인구_소득_소비.csv', encoding = 'utf-8-sig')
